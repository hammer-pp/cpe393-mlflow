# %% [markdown]
# Scenario 1: A single data scientist participating in an ML competition
#
# MLflow setup:
#
# Tracking server: no
# Backend store: local filesystem
# Artifacts store: local filesystem
#
# The experiments can be explored locally by launching the MLflow UI.

# %%
import mlflow

# %%
print(f"tracking URI: '{mlflow.get_tracking_uri()}'")
# Out:
# tracking URI: 'file:///c:/Users/usEr/Documents/GitHub/cpe393-mlflow/mlruns'

# %%
mlflow.search_experiments()
# Out:
# WARNING:root:Malformed experiment '0'. Detailed error Yaml file 'C:\Users\usEr\Documents\GitHub\cpe393-mlflow\mlruns\0\meta.yaml' does not exist.
# Traceback (most recent call last):
#   File "C:\Users\usEr\AppData\Roaming\Python\Python312\site-packages\mlflow\store\tracking\file_store.py", line 329, in search_experiments
#     exp = self._get_experiment(exp_id, view_type)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\usEr\AppData\Roaming\Python\Python312\site-packages\mlflow\store\tracking\file_store.py", line 427, in _get_experiment
#     meta = FileStore._read_yaml(experiment_dir, FileStore.META_DATA_FILE_NAME)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\usEr\AppData\Roaming\Python\Python312\site-packages\mlflow\store\tracking\file_store.py", line 1373, in _read_yaml
#     return _read_helper(root, file_name, attempts_remaining=retries)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\usEr\AppData\Roaming\Python\Python312\site-packages\mlflow\store\tracking\file_store.py", line 1366, in _read_helper
#     result = read_yaml(root, file_name)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\usEr\AppData\Roaming\Python\Python312\site-packages\mlflow\utils\file_utils.py", line 310, in read_yaml
#     raise MissingConfigException(f"Yaml file '{file_path}' does not exist.")
# mlflow.exceptions.MissingConfigException: Yaml file 'C:\Users\usEr\Documents\GitHub\cpe393-mlflow\mlruns\0\meta.yaml' does not exist.
# WARNING:root:Malformed experiment '1'. Detailed error Yaml file 'C:\Users\usEr\Documents\GitHub\cpe393-mlflow\mlruns\1\meta.yaml' does not exist.
# Traceback (most recent call last):
#   File "C:\Users\usEr\AppData\Roaming\Python\Python312\site-packages\mlflow\store\tracking\file_store.py", line 329, in search_experiments
#     exp = self._get_experiment(exp_id, view_type)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\usEr\AppData\Roaming\Python\Python312\site-packages\mlflow\store\tracking\file_store.py", line 427, in _get_experiment
#     meta = FileStore._read_yaml(experiment_dir, FileStore.META_DATA_FILE_NAME)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\usEr\AppData\Roaming\Python\Python312\site-packages\mlflow\store\tracking\file_store.py", line 1373, in _read_yaml
#     return _read_helper(root, file_name, attempts_remaining=retries)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\usEr\AppData\Roaming\Python\Python312\site-packages\mlflow\store\tracking\file_store.py", line 1366, in _read_helper
#     result = read_yaml(root, file_name)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\usEr\AppData\Roaming\Python\Python312\site-packages\mlflow\utils\file_utils.py", line 310, in read_yaml
#     raise MissingConfigException(f"Yaml file '{file_path}' does not exist.")
# mlflow.exceptions.MissingConfigException: Yaml file 'C:\Users\usEr\Documents\GitHub\cpe393-mlflow\mlruns\1\meta.yaml' does not exist.
# WARNING:root:Malformed experiment '336581384817255671'. Detailed error Yaml file 'C:\Users\usEr\Documents\GitHub\cpe393-mlflow\mlruns\336581384817255671\meta.yaml' does not exist.
# Traceback (most recent call last):
#   File "C:\Users\usEr\AppData\Roaming\Python\Python312\site-packages\mlflow\store\tracking\file_store.py", line 329, in search_experiments
#     exp = self._get_experiment(exp_id, view_type)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\usEr\AppData\Roaming\Python\Python312\site-packages\mlflow\store\tracking\file_store.py", line 427, in _get_experiment
#     meta = FileStore._read_yaml(experiment_dir, FileStore.META_DATA_FILE_NAME)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\usEr\AppData\Roaming\Python\Python312\site-packages\mlflow\store\tracking\file_store.py", line 1373, in _read_yaml
#     return _read_helper(root, file_name, attempts_remaining=retries)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\usEr\AppData\Roaming\Python\Python312\site-packages\mlflow\store\tracking\file_store.py", line 1366, in _read_helper
#     result = read_yaml(root, file_name)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\usEr\AppData\Roaming\Python\Python312\site-packages\mlflow\utils\file_utils.py", line 310, in read_yaml
#     raise MissingConfigException(f"Yaml file '{file_path}' does not exist.")
# mlflow.exceptions.MissingConfigException: Yaml file 'C:\Users\usEr\Documents\GitHub\cpe393-mlflow\mlruns\336581384817255671\meta.yaml' does not exist.
# WARNING:root:Malformed experiment '342701827177914614'. Detailed error Yaml file 'C:\Users\usEr\Documents\GitHub\cpe393-mlflow\mlruns\342701827177914614\meta.yaml' does not exist.
# Traceback (most recent call last):
#   File "C:\Users\usEr\AppData\Roaming\Python\Python312\site-packages\mlflow\store\tracking\file_store.py", line 329, in search_experiments
#     exp = self._get_experiment(exp_id, view_type)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\usEr\AppData\Roaming\Python\Python312\site-packages\mlflow\store\tracking\file_store.py", line 427, in _get_experiment
#     meta = FileStore._read_yaml(experiment_dir, FileStore.META_DATA_FILE_NAME)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\usEr\AppData\Roaming\Python\Python312\site-packages\mlflow\store\tracking\file_store.py", line 1373, in _read_yaml
#     return _read_helper(root, file_name, attempts_remaining=retries)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\usEr\AppData\Roaming\Python\Python312\site-packages\mlflow\store\tracking\file_store.py", line 1366, in _read_helper
#     result = read_yaml(root, file_name)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\usEr\AppData\Roaming\Python\Python312\site-packages\mlflow\utils\file_utils.py", line 310, in read_yaml
#     raise MissingConfigException(f"Yaml file '{file_path}' does not exist.")
# mlflow.exceptions.MissingConfigException: Yaml file 'C:\Users\usEr\Documents\GitHub\cpe393-mlflow\mlruns\342701827177914614\meta.yaml' does not exist.
# WARNING:root:Malformed experiment '669278529031826307'. Detailed error Yaml file 'C:\Users\usEr\Documents\GitHub\cpe393-mlflow\mlruns\669278529031826307\meta.yaml' does not exist.
# Traceback (most recent call last):
#   File "C:\Users\usEr\AppData\Roaming\Python\Python312\site-packages\mlflow\store\tracking\file_store.py", line 329, in search_experiments
#     exp = self._get_experiment(exp_id, view_type)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\usEr\AppData\Roaming\Python\Python312\site-packages\mlflow\store\tracking\file_store.py", line 427, in _get_experiment
#     meta = FileStore._read_yaml(experiment_dir, FileStore.META_DATA_FILE_NAME)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\usEr\AppData\Roaming\Python\Python312\site-packages\mlflow\store\tracking\file_store.py", line 1373, in _read_yaml
#     return _read_helper(root, file_name, attempts_remaining=retries)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\usEr\AppData\Roaming\Python\Python312\site-packages\mlflow\store\tracking\file_store.py", line 1366, in _read_helper
#     result = read_yaml(root, file_name)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\usEr\AppData\Roaming\Python\Python312\site-packages\mlflow\utils\file_utils.py", line 310, in read_yaml
#     raise MissingConfigException(f"Yaml file '{file_path}' does not exist.")
# mlflow.exceptions.MissingConfigException: Yaml file 'C:\Users\usEr\Documents\GitHub\cpe393-mlflow\mlruns\669278529031826307\meta.yaml' does not exist.
# WARNING:root:Malformed experiment '772891878219575210'. Detailed error Yaml file 'C:\Users\usEr\Documents\GitHub\cpe393-mlflow\mlruns\772891878219575210\meta.yaml' does not exist.
# Traceback (most recent call last):
#   File "C:\Users\usEr\AppData\Roaming\Python\Python312\site-packages\mlflow\store\tracking\file_store.py", line 329, in search_experiments
#     exp = self._get_experiment(exp_id, view_type)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\usEr\AppData\Roaming\Python\Python312\site-packages\mlflow\store\tracking\file_store.py", line 427, in _get_experiment
#     meta = FileStore._read_yaml(experiment_dir, FileStore.META_DATA_FILE_NAME)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\usEr\AppData\Roaming\Python\Python312\site-packages\mlflow\store\tracking\file_store.py", line 1373, in _read_yaml
#     return _read_helper(root, file_name, attempts_remaining=retries)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\usEr\AppData\Roaming\Python\Python312\site-packages\mlflow\store\tracking\file_store.py", line 1366, in _read_helper
#     result = read_yaml(root, file_name)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\usEr\AppData\Roaming\Python\Python312\site-packages\mlflow\utils\file_utils.py", line 310, in read_yaml
#     raise MissingConfigException(f"Yaml file '{file_path}' does not exist.")
# mlflow.exceptions.MissingConfigException: Yaml file 'C:\Users\usEr\Documents\GitHub\cpe393-mlflow\mlruns\772891878219575210\meta.yaml' does not exist.
# [<Experiment: artifact_location='mlflow-artifacts:/359132417154449851', creation_time=1747323167225, experiment_id='359132417154449851', last_update_time=1747323167225, lifecycle_stage='active', name='NYC Taxi tips experiment', tags={}>,
#  <Experiment: artifact_location='mlflow-artifacts:/474160717678596706', creation_time=1747323046927, experiment_id='474160717678596706', last_update_time=1747323046927, lifecycle_stage='active', name='my-experiment-2', tags={}>,
#  <Experiment: artifact_location='file:///c:/Users/usEr/Documents/GitHub/cpe393-mlflow/mlruns/639091011841886520', creation_time=1747165230363, experiment_id='639091011841886520', last_update_time=1747165230363, lifecycle_stage='active', name='my-experiment-1', tags={}>]

# %% [markdown]
# Creating an experiment and logging a new run

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.datasets import load_iris
from sklearn.metrics import accuracy_score

mlflow.set_experiment("my-experiment-1")

with mlflow.start_run():

    X, y = load_iris(return_X_y=True)

    params = {"C": 0.1, "random_state": 42}
    mlflow.log_params(params)

    lr = LogisticRegression(**params).fit(X, y)
    y_pred = lr.predict(X)
    mlflow.log_metric("accuracy", accuracy_score(y, y_pred))

    mlflow.sklearn.log_model(lr, artifact_path="models")
    print(f"default artifacts URI: '{mlflow.get_artifact_uri()}'")
# Out:
# WARNING:root:Malformed experiment '0'. Detailed error Yaml file 'C:\Users\usEr\Documents\GitHub\cpe393-mlflow\mlruns\0\meta.yaml' does not exist.
# Traceback (most recent call last):
#   File "C:\Users\usEr\AppData\Roaming\Python\Python312\site-packages\mlflow\store\tracking\file_store.py", line 329, in search_experiments
#     exp = self._get_experiment(exp_id, view_type)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\usEr\AppData\Roaming\Python\Python312\site-packages\mlflow\store\tracking\file_store.py", line 427, in _get_experiment
#     meta = FileStore._read_yaml(experiment_dir, FileStore.META_DATA_FILE_NAME)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\usEr\AppData\Roaming\Python\Python312\site-packages\mlflow\store\tracking\file_store.py", line 1373, in _read_yaml
#     return _read_helper(root, file_name, attempts_remaining=retries)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\usEr\AppData\Roaming\Python\Python312\site-packages\mlflow\store\tracking\file_store.py", line 1366, in _read_helper
#     result = read_yaml(root, file_name)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\usEr\AppData\Roaming\Python\Python312\site-packages\mlflow\utils\file_utils.py", line 310, in read_yaml
#     raise MissingConfigException(f"Yaml file '{file_path}' does not exist.")
# mlflow.exceptions.MissingConfigException: Yaml file 'C:\Users\usEr\Documents\GitHub\cpe393-mlflow\mlruns\0\meta.yaml' does not exist.
# WARNING:root:Malformed experiment '1'. Detailed error Yaml file 'C:\Users\usEr\Documents\GitHub\cpe393-mlflow\mlruns\1\meta.yaml' does not exist.
# Traceback (most recent call last):
#   File "C:\Users\usEr\AppData\Roaming\Python\Python312\site-packages\mlflow\store\tracking\file_store.py", line 329, in search_experiments
#     exp = self._get_experiment(exp_id, view_type)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\usEr\AppData\Roaming\Python\Python312\site-packages\mlflow\store\tracking\file_store.py", line 427, in _get_experiment
#     meta = FileStore._read_yaml(experiment_dir, FileStore.META_DATA_FILE_NAME)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\usEr\AppData\Roaming\Python\Python312\site-packages\mlflow\store\tracking\file_store.py", line 1373, in _read_yaml
#     return _read_helper(root, file_name, attempts_remaining=retries)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\usEr\AppData\Roaming\Python\Python312\site-packages\mlflow\store\tracking\file_store.py", line 1366, in _read_helper
#     result = read_yaml(root, file_name)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\usEr\AppData\Roaming\Python\Python312\site-packages\mlflow\utils\file_utils.py", line 310, in read_yaml
#     raise MissingConfigException(f"Yaml file '{file_path}' does not exist.")
# mlflow.exceptions.MissingConfigException: Yaml file 'C:\Users\usEr\Documents\GitHub\cpe393-mlflow\mlruns\1\meta.yaml' does not exist.
# WARNING:root:Malformed experiment '336581384817255671'. Detailed error Yaml file 'C:\Users\usEr\Documents\GitHub\cpe393-mlflow\mlruns\336581384817255671\meta.yaml' does not exist.
# Traceback (most recent call last):
#   File "C:\Users\usEr\AppData\Roaming\Python\Python312\site-packages\mlflow\store\tracking\file_store.py", line 329, in search_experiments
#     exp = self._get_experiment(exp_id, view_type)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\usEr\AppData\Roaming\Python\Python312\site-packages\mlflow\store\tracking\file_store.py", line 427, in _get_experiment
#     meta = FileStore._read_yaml(experiment_dir, FileStore.META_DATA_FILE_NAME)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\usEr\AppData\Roaming\Python\Python312\site-packages\mlflow\store\tracking\file_store.py", line 1373, in _read_yaml
#     return _read_helper(root, file_name, attempts_remaining=retries)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\usEr\AppData\Roaming\Python\Python312\site-packages\mlflow\store\tracking\file_store.py", line 1366, in _read_helper
#     result = read_yaml(root, file_name)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\usEr\AppData\Roaming\Python\Python312\site-packages\mlflow\utils\file_utils.py", line 310, in read_yaml
#     raise MissingConfigException(f"Yaml file '{file_path}' does not exist.")
# mlflow.exceptions.MissingConfigException: Yaml file 'C:\Users\usEr\Documents\GitHub\cpe393-mlflow\mlruns\336581384817255671\meta.yaml' does not exist.
# WARNING:root:Malformed experiment '342701827177914614'. Detailed error Yaml file 'C:\Users\usEr\Documents\GitHub\cpe393-mlflow\mlruns\342701827177914614\meta.yaml' does not exist.
# Traceback (most recent call last):
#   File "C:\Users\usEr\AppData\Roaming\Python\Python312\site-packages\mlflow\store\tracking\file_store.py", line 329, in search_experiments
#     exp = self._get_experiment(exp_id, view_type)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\usEr\AppData\Roaming\Python\Python312\site-packages\mlflow\store\tracking\file_store.py", line 427, in _get_experiment
#     meta = FileStore._read_yaml(experiment_dir, FileStore.META_DATA_FILE_NAME)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\usEr\AppData\Roaming\Python\Python312\site-packages\mlflow\store\tracking\file_store.py", line 1373, in _read_yaml
#     return _read_helper(root, file_name, attempts_remaining=retries)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\usEr\AppData\Roaming\Python\Python312\site-packages\mlflow\store\tracking\file_store.py", line 1366, in _read_helper
#     result = read_yaml(root, file_name)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\usEr\AppData\Roaming\Python\Python312\site-packages\mlflow\utils\file_utils.py", line 310, in read_yaml
#     raise MissingConfigException(f"Yaml file '{file_path}' does not exist.")
# mlflow.exceptions.MissingConfigException: Yaml file 'C:\Users\usEr\Documents\GitHub\cpe393-mlflow\mlruns\342701827177914614\meta.yaml' does not exist.
# WARNING:root:Malformed experiment '669278529031826307'. Detailed error Yaml file 'C:\Users\usEr\Documents\GitHub\cpe393-mlflow\mlruns\669278529031826307\meta.yaml' does not exist.
# Traceback (most recent call last):
#   File "C:\Users\usEr\AppData\Roaming\Python\Python312\site-packages\mlflow\store\tracking\file_store.py", line 329, in search_experiments
#     exp = self._get_experiment(exp_id, view_type)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\usEr\AppData\Roaming\Python\Python312\site-packages\mlflow\store\tracking\file_store.py", line 427, in _get_experiment
#     meta = FileStore._read_yaml(experiment_dir, FileStore.META_DATA_FILE_NAME)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\usEr\AppData\Roaming\Python\Python312\site-packages\mlflow\store\tracking\file_store.py", line 1373, in _read_yaml
#     return _read_helper(root, file_name, attempts_remaining=retries)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\usEr\AppData\Roaming\Python\Python312\site-packages\mlflow\store\tracking\file_store.py", line 1366, in _read_helper
#     result = read_yaml(root, file_name)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\usEr\AppData\Roaming\Python\Python312\site-packages\mlflow\utils\file_utils.py", line 310, in read_yaml
#     raise MissingConfigException(f"Yaml file '{file_path}' does not exist.")
# mlflow.exceptions.MissingConfigException: Yaml file 'C:\Users\usEr\Documents\GitHub\cpe393-mlflow\mlruns\669278529031826307\meta.yaml' does not exist.
# WARNING:root:Malformed experiment '772891878219575210'. Detailed error Yaml file 'C:\Users\usEr\Documents\GitHub\cpe393-mlflow\mlruns\772891878219575210\meta.yaml' does not exist.
# Traceback (most recent call last):
#   File "C:\Users\usEr\AppData\Roaming\Python\Python312\site-packages\mlflow\store\tracking\file_store.py", line 329, in search_experiments
#     exp = self._get_experiment(exp_id, view_type)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\usEr\AppData\Roaming\Python\Python312\site-packages\mlflow\store\tracking\file_store.py", line 427, in _get_experiment
#     meta = FileStore._read_yaml(experiment_dir, FileStore.META_DATA_FILE_NAME)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\usEr\AppData\Roaming\Python\Python312\site-packages\mlflow\store\tracking\file_store.py", line 1373, in _read_yaml
#     return _read_helper(root, file_name, attempts_remaining=retries)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\usEr\AppData\Roaming\Python\Python312\site-packages\mlflow\store\tracking\file_store.py", line 1366, in _read_helper
#     result = read_yaml(root, file_name)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\usEr\AppData\Roaming\Python\Python312\site-packages\mlflow\utils\file_utils.py", line 310, in read_yaml
#     raise MissingConfigException(f"Yaml file '{file_path}' does not exist.")
# mlflow.exceptions.MissingConfigException: Yaml file 'C:\Users\usEr\Documents\GitHub\cpe393-mlflow\mlruns\772891878219575210\meta.yaml' does not exist.
# WARNING:root:Malformed experiment '528627032359263006'. Detailed error Yaml file 'C:\Users\usEr\Documents\GitHub\cpe393-mlflow\mlruns\.trash\528627032359263006\meta.yaml' does not exist.
# Traceback (most recent call last):
#   File "C:\Users\usEr\AppData\Roaming\Python\Python312\site-packages\mlflow\store\tracking\file_store.py", line 329, in search_experiments
#     exp = self._get_experiment(exp_id, view_type)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\usEr\AppData\Roaming\Python\Python312\site-packages\mlflow\store\tracking\file_store.py", line 427, in _get_experiment
#     meta = FileStore._read_yaml(experiment_dir, FileStore.META_DATA_FILE_NAME)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\usEr\AppData\Roaming\Python\Python312\site-packages\mlflow\store\tracking\file_store.py", line 1373, in _read_yaml
#     return _read_helper(root, file_name, attempts_remaining=retries)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\usEr\AppData\Roaming\Python\Python312\site-packages\mlflow\store\tracking\file_store.py", line 1366, in _read_helper
#     result = read_yaml(root, file_name)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\usEr\AppData\Roaming\Python\Python312\site-packages\mlflow\utils\file_utils.py", line 310, in read_yaml
#     raise MissingConfigException(f"Yaml file '{file_path}' does not exist.")
# mlflow.exceptions.MissingConfigException: Yaml file 'C:\Users\usEr\Documents\GitHub\cpe393-mlflow\mlruns\.trash\528627032359263006\meta.yaml' does not exist.
# WARNING:root:Malformed experiment '661934626148225633'. Detailed error Yaml file 'C:\Users\usEr\Documents\GitHub\cpe393-mlflow\mlruns\.trash\661934626148225633\meta.yaml' does not exist.
# Traceback (most recent call last):
#   File "C:\Users\usEr\AppData\Roaming\Python\Python312\site-packages\mlflow\store\tracking\file_store.py", line 329, in search_experiments
#     exp = self._get_experiment(exp_id, view_type)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\usEr\AppData\Roaming\Python\Python312\site-packages\mlflow\store\tracking\file_store.py", line 427, in _get_experiment
#     meta = FileStore._read_yaml(experiment_dir, FileStore.META_DATA_FILE_NAME)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\usEr\AppData\Roaming\Python\Python312\site-packages\mlflow\store\tracking\file_store.py", line 1373, in _read_yaml
#     return _read_helper(root, file_name, attempts_remaining=retries)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\usEr\AppData\Roaming\Python\Python312\site-packages\mlflow\store\tracking\file_store.py", line 1366, in _read_helper
#     result = read_yaml(root, file_name)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\usEr\AppData\Roaming\Python\Python312\site-packages\mlflow\utils\file_utils.py", line 310, in read_yaml
#     raise MissingConfigException(f"Yaml file '{file_path}' does not exist.")
# mlflow.exceptions.MissingConfigException: Yaml file 'C:\Users\usEr\Documents\GitHub\cpe393-mlflow\mlruns\.trash\661934626148225633\meta.yaml' does not exist.
# WARNING:root:Malformed experiment '697913763857921441'. Detailed error Yaml file 'C:\Users\usEr\Documents\GitHub\cpe393-mlflow\mlruns\.trash\697913763857921441\meta.yaml' does not exist.
# Traceback (most recent call last):
#   File "C:\Users\usEr\AppData\Roaming\Python\Python312\site-packages\mlflow\store\tracking\file_store.py", line 329, in search_experiments
#     exp = self._get_experiment(exp_id, view_type)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\usEr\AppData\Roaming\Python\Python312\site-packages\mlflow\store\tracking\file_store.py", line 427, in _get_experiment
#     meta = FileStore._read_yaml(experiment_dir, FileStore.META_DATA_FILE_NAME)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\usEr\AppData\Roaming\Python\Python312\site-packages\mlflow\store\tracking\file_store.py", line 1373, in _read_yaml
#     return _read_helper(root, file_name, attempts_remaining=retries)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\usEr\AppData\Roaming\Python\Python312\site-packages\mlflow\store\tracking\file_store.py", line 1366, in _read_helper
#     result = read_yaml(root, file_name)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\usEr\AppData\Roaming\Python\Python312\site-packages\mlflow\utils\file_utils.py", line 310, in read_yaml
#     raise MissingConfigException(f"Yaml file '{file_path}' does not exist.")
# mlflow.exceptions.MissingConfigException: Yaml file 'C:\Users\usEr\Documents\GitHub\cpe393-mlflow\mlruns\.trash\697913763857921441\meta.yaml' does not exist.
# 2025/05/15 22:37:21 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# default artifacts URI: 'file:///c:/Users/usEr/Documents/GitHub/cpe393-mlflow/mlruns/639091011841886520/a901c8f026cd4c49bfb94a18b2a25c2e/artifacts'

# %%
mlflow.search_experiments()
# Out:
# WARNING:root:Malformed experiment '0'. Detailed error Yaml file 'C:\Users\usEr\Documents\GitHub\cpe393-mlflow\mlruns\0\meta.yaml' does not exist.
# Traceback (most recent call last):
#   File "C:\Users\usEr\AppData\Roaming\Python\Python312\site-packages\mlflow\store\tracking\file_store.py", line 329, in search_experiments
#     exp = self._get_experiment(exp_id, view_type)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\usEr\AppData\Roaming\Python\Python312\site-packages\mlflow\store\tracking\file_store.py", line 427, in _get_experiment
#     meta = FileStore._read_yaml(experiment_dir, FileStore.META_DATA_FILE_NAME)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\usEr\AppData\Roaming\Python\Python312\site-packages\mlflow\store\tracking\file_store.py", line 1373, in _read_yaml
#     return _read_helper(root, file_name, attempts_remaining=retries)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\usEr\AppData\Roaming\Python\Python312\site-packages\mlflow\store\tracking\file_store.py", line 1366, in _read_helper
#     result = read_yaml(root, file_name)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\usEr\AppData\Roaming\Python\Python312\site-packages\mlflow\utils\file_utils.py", line 310, in read_yaml
#     raise MissingConfigException(f"Yaml file '{file_path}' does not exist.")
# mlflow.exceptions.MissingConfigException: Yaml file 'C:\Users\usEr\Documents\GitHub\cpe393-mlflow\mlruns\0\meta.yaml' does not exist.
# WARNING:root:Malformed experiment '1'. Detailed error Yaml file 'C:\Users\usEr\Documents\GitHub\cpe393-mlflow\mlruns\1\meta.yaml' does not exist.
# Traceback (most recent call last):
#   File "C:\Users\usEr\AppData\Roaming\Python\Python312\site-packages\mlflow\store\tracking\file_store.py", line 329, in search_experiments
#     exp = self._get_experiment(exp_id, view_type)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\usEr\AppData\Roaming\Python\Python312\site-packages\mlflow\store\tracking\file_store.py", line 427, in _get_experiment
#     meta = FileStore._read_yaml(experiment_dir, FileStore.META_DATA_FILE_NAME)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\usEr\AppData\Roaming\Python\Python312\site-packages\mlflow\store\tracking\file_store.py", line 1373, in _read_yaml
#     return _read_helper(root, file_name, attempts_remaining=retries)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\usEr\AppData\Roaming\Python\Python312\site-packages\mlflow\store\tracking\file_store.py", line 1366, in _read_helper
#     result = read_yaml(root, file_name)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\usEr\AppData\Roaming\Python\Python312\site-packages\mlflow\utils\file_utils.py", line 310, in read_yaml
#     raise MissingConfigException(f"Yaml file '{file_path}' does not exist.")
# mlflow.exceptions.MissingConfigException: Yaml file 'C:\Users\usEr\Documents\GitHub\cpe393-mlflow\mlruns\1\meta.yaml' does not exist.
# WARNING:root:Malformed experiment '336581384817255671'. Detailed error Yaml file 'C:\Users\usEr\Documents\GitHub\cpe393-mlflow\mlruns\336581384817255671\meta.yaml' does not exist.
# Traceback (most recent call last):
#   File "C:\Users\usEr\AppData\Roaming\Python\Python312\site-packages\mlflow\store\tracking\file_store.py", line 329, in search_experiments
#     exp = self._get_experiment(exp_id, view_type)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\usEr\AppData\Roaming\Python\Python312\site-packages\mlflow\store\tracking\file_store.py", line 427, in _get_experiment
#     meta = FileStore._read_yaml(experiment_dir, FileStore.META_DATA_FILE_NAME)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\usEr\AppData\Roaming\Python\Python312\site-packages\mlflow\store\tracking\file_store.py", line 1373, in _read_yaml
#     return _read_helper(root, file_name, attempts_remaining=retries)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\usEr\AppData\Roaming\Python\Python312\site-packages\mlflow\store\tracking\file_store.py", line 1366, in _read_helper
#     result = read_yaml(root, file_name)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\usEr\AppData\Roaming\Python\Python312\site-packages\mlflow\utils\file_utils.py", line 310, in read_yaml
#     raise MissingConfigException(f"Yaml file '{file_path}' does not exist.")
# mlflow.exceptions.MissingConfigException: Yaml file 'C:\Users\usEr\Documents\GitHub\cpe393-mlflow\mlruns\336581384817255671\meta.yaml' does not exist.
# WARNING:root:Malformed experiment '342701827177914614'. Detailed error Yaml file 'C:\Users\usEr\Documents\GitHub\cpe393-mlflow\mlruns\342701827177914614\meta.yaml' does not exist.
# Traceback (most recent call last):
#   File "C:\Users\usEr\AppData\Roaming\Python\Python312\site-packages\mlflow\store\tracking\file_store.py", line 329, in search_experiments
#     exp = self._get_experiment(exp_id, view_type)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\usEr\AppData\Roaming\Python\Python312\site-packages\mlflow\store\tracking\file_store.py", line 427, in _get_experiment
#     meta = FileStore._read_yaml(experiment_dir, FileStore.META_DATA_FILE_NAME)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\usEr\AppData\Roaming\Python\Python312\site-packages\mlflow\store\tracking\file_store.py", line 1373, in _read_yaml
#     return _read_helper(root, file_name, attempts_remaining=retries)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\usEr\AppData\Roaming\Python\Python312\site-packages\mlflow\store\tracking\file_store.py", line 1366, in _read_helper
#     result = read_yaml(root, file_name)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\usEr\AppData\Roaming\Python\Python312\site-packages\mlflow\utils\file_utils.py", line 310, in read_yaml
#     raise MissingConfigException(f"Yaml file '{file_path}' does not exist.")
# mlflow.exceptions.MissingConfigException: Yaml file 'C:\Users\usEr\Documents\GitHub\cpe393-mlflow\mlruns\342701827177914614\meta.yaml' does not exist.
# WARNING:root:Malformed experiment '669278529031826307'. Detailed error Yaml file 'C:\Users\usEr\Documents\GitHub\cpe393-mlflow\mlruns\669278529031826307\meta.yaml' does not exist.
# Traceback (most recent call last):
#   File "C:\Users\usEr\AppData\Roaming\Python\Python312\site-packages\mlflow\store\tracking\file_store.py", line 329, in search_experiments
#     exp = self._get_experiment(exp_id, view_type)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\usEr\AppData\Roaming\Python\Python312\site-packages\mlflow\store\tracking\file_store.py", line 427, in _get_experiment
#     meta = FileStore._read_yaml(experiment_dir, FileStore.META_DATA_FILE_NAME)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\usEr\AppData\Roaming\Python\Python312\site-packages\mlflow\store\tracking\file_store.py", line 1373, in _read_yaml
#     return _read_helper(root, file_name, attempts_remaining=retries)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\usEr\AppData\Roaming\Python\Python312\site-packages\mlflow\store\tracking\file_store.py", line 1366, in _read_helper
#     result = read_yaml(root, file_name)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\usEr\AppData\Roaming\Python\Python312\site-packages\mlflow\utils\file_utils.py", line 310, in read_yaml
#     raise MissingConfigException(f"Yaml file '{file_path}' does not exist.")
# mlflow.exceptions.MissingConfigException: Yaml file 'C:\Users\usEr\Documents\GitHub\cpe393-mlflow\mlruns\669278529031826307\meta.yaml' does not exist.
# WARNING:root:Malformed experiment '772891878219575210'. Detailed error Yaml file 'C:\Users\usEr\Documents\GitHub\cpe393-mlflow\mlruns\772891878219575210\meta.yaml' does not exist.
# Traceback (most recent call last):
#   File "C:\Users\usEr\AppData\Roaming\Python\Python312\site-packages\mlflow\store\tracking\file_store.py", line 329, in search_experiments
#     exp = self._get_experiment(exp_id, view_type)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\usEr\AppData\Roaming\Python\Python312\site-packages\mlflow\store\tracking\file_store.py", line 427, in _get_experiment
#     meta = FileStore._read_yaml(experiment_dir, FileStore.META_DATA_FILE_NAME)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\usEr\AppData\Roaming\Python\Python312\site-packages\mlflow\store\tracking\file_store.py", line 1373, in _read_yaml
#     return _read_helper(root, file_name, attempts_remaining=retries)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\usEr\AppData\Roaming\Python\Python312\site-packages\mlflow\store\tracking\file_store.py", line 1366, in _read_helper
#     result = read_yaml(root, file_name)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\usEr\AppData\Roaming\Python\Python312\site-packages\mlflow\utils\file_utils.py", line 310, in read_yaml
#     raise MissingConfigException(f"Yaml file '{file_path}' does not exist.")
# mlflow.exceptions.MissingConfigException: Yaml file 'C:\Users\usEr\Documents\GitHub\cpe393-mlflow\mlruns\772891878219575210\meta.yaml' does not exist.
# [<Experiment: artifact_location='mlflow-artifacts:/359132417154449851', creation_time=1747323167225, experiment_id='359132417154449851', last_update_time=1747323167225, lifecycle_stage='active', name='NYC Taxi tips experiment', tags={}>,
#  <Experiment: artifact_location='mlflow-artifacts:/474160717678596706', creation_time=1747323046927, experiment_id='474160717678596706', last_update_time=1747323046927, lifecycle_stage='active', name='my-experiment-2', tags={}>,
#  <Experiment: artifact_location='file:///c:/Users/usEr/Documents/GitHub/cpe393-mlflow/mlruns/639091011841886520', creation_time=1747165230363, experiment_id='639091011841886520', last_update_time=1747165230363, lifecycle_stage='active', name='my-experiment-1', tags={}>]
